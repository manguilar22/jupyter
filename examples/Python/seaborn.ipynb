# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt 
# %matplotlib inline

# %%
tips = sns.load_dataset("tips")

# %%
tips.head()
# Out:
#    total_bill   tip     sex smoker  day    time  size
# 0       16.99  1.01  Female     No  Sun  Dinner     2
# 1       10.34  1.66    Male     No  Sun  Dinner     3
# 2       21.01  3.50    Male     No  Sun  Dinner     3
# 3       23.68  3.31    Male     No  Sun  Dinner     2
# 4       24.59  3.61  Female     No  Sun  Dinner     4

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %%
# tips.info
# tips.describe

# %%
sns.boxplot(data=tips,x="day",y="tip",hue="sex")

# %%
sns.swarmplot(data=tips,x="total_bill",y="tip",hue="sex")

# %%
sns.lmplot(data=tips,x="total_bill",y="tip",hue="sex",fit_reg=False)

# %%
tips.dtypes
# Out:
# total_bill     float64
# tip            float64
# sex           category
# smoker        category
# day           category
# time          category
# size             int64
# dtype: object

# %% [markdown]
# ### Plotting Context for Seaborn
# * **paper**
# * **talk**
# * **poster**
# ---
# #### Examples
# ```python
# set_context("paper")
#
# set_context("talk", font_scale=1.4)
#
# set_context("talk", rc={"lines.linewidth": 2})
# ```

# %%
sns.set_context("talk")

# %%
sns.lmplot(data=tips,x="tip",y="total_bill",fit_reg=True,hue="smoker")

# %%
 kernel_options = ['gau' ,'cos' , 'biw' , 'epa' , 'tri' , 'triw' ]

# %%
sns.kdeplot(data=tips[["total_bill","tip"]], n_levels=10, cmap="RdBu",kernel="gau")
# Out:
# /home/user/Documents/anaconda3/lib/python3.6/site-packages/seaborn/distributions.py:645: UserWarning: Passing a 2D dataset for a bivariate plot is deprecated in favor of kdeplot(x, y), and it will cause an error in future versions. Please update your code.
#   warnings.warn(warn_msg, UserWarning)

# %%
c = tips[["total_bill","tip","size"]].corr()
c
# Out:
#             total_bill       tip      size
# total_bill    1.000000  0.675734  0.598315
# tip           0.675734  1.000000  0.489299
# size          0.598315  0.489299  1.000000

# %%
sns.heatmap(c,linewidths=3,linecolor="black",annot=True,cmap="rainbow")
